# %% [markdown]
# # EDA for Processed Recipes Dataset

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %% [markdown]
# ## Explore Reviews Dataset

# %%
# Load preprocessed reviews data
reviews_df = pd.read_csv('../data/processed_reviews.csv')
reviews_df.head()
# Out:
#    AuthorId  RecipeId  Rating  \
# 0      2008       992       5
# 1      1634      4384       4
# 2      2046      4523       2
# 3      1773      7435       5
# 4      2085        44       5
#
#                                               Review  \
# 0       better than any you can get at a restaurant!
# 1  I cut back on the mayo, and made up the differ...
# 2  i think i did something wrong because i could ...
# 3  easily the best i have ever had. juicy flavorf...
# 4                                 An excellent dish.
#
#                   ReviewDate  ReviewLength  ReviewWordCount  \
# 0  2000-01-25 21:44:00+00:00            44                9
# 1  2001-10-17 16:49:59+00:00           102               21
# 2  2000-02-25 09:00:00+00:00            91               16
# 3  2000-03-13 21:15:00+00:00           117               21
# 4  2000-03-28 12:51:00+00:00            18                3
#
#    IsSubstantialReview  SentimentPolarity  SentimentSubjectivity  ...  \
# ...

# %%
reviews_df.columns
# Out:
# Index(['AuthorId', 'RecipeId', 'Rating', 'Review', 'ReviewDate',
#        'ReviewLength', 'ReviewWordCount', 'IsSubstantialReview',
#        'SentimentPolarity', 'SentimentSubjectivity', 'SentimentCategory',
#        'IsPositiveSentiment', 'IsNegativeSentiment', 'HasHealthPositive',
#        'HasHealthNegative', 'HasTastePositive', 'HasTasteNegative',
#        'HealthPerceptionScore', 'TastePerceptionScore', 'UserAvgRating',
#        'UserReviewCount', 'UserAvgSentiment', 'UserHealthyRecipePreference',
#        'IsHealthConsciousUser', 'UserEngagementLevel', 'UserRatingBehavior',
#        'HealthyRecipePositiveReview', 'UserHealthRecipeAlignment'],
#       dtype='object')

# %%
reviews_df.info()
reviews_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1401982 entries, 0 to 1401981
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   AuthorId                     1401982 non-null  int64
#  1   RecipeId                     1401982 non-null  int64
#  2   Rating                       1401982 non-null  int64
#  3   Review                       1401765 non-null  object
#  4   ReviewDate                   1401982 non-null  object
#  5   ReviewLength                 1401982 non-null  int64
#  6   ReviewWordCount              1401982 non-null  int64
#  7   IsSubstantialReview          1401982 non-null  bool
#  8   SentimentPolarity            1401982 non-null  float64
#  9   SentimentSubjectivity        1401982 non-null  float64
#  10  SentimentCategory            1401530 non-null  object
#  11  IsPositiveSentiment          1401982 non-null  bool
# ...

# %%
pd.crosstab(reviews_df['UserEngagementLevel'], reviews_df['IsHealthConsciousUser']).plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='UserEngagementLevel'>

# %%
reviews_df['SentimentPolarity'].hist(bins=50)
plt.title("Sentiment Polarity")
# Out:
# Text(0.5, 1.0, 'Sentiment Polarity')

# %%
reviews_df['SentimentCategory'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SentimentCategory'>

# %%
sns.scatterplot(data=reviews_df, x='TastePerceptionScore', y='HealthPerceptionScore', hue='SentimentCategory')
# Out:
# <Axes: xlabel='TastePerceptionScore', ylabel='HealthPerceptionScore'>

# %%
reviews_df['HealthyRecipePositiveReview'].value_counts(normalize=True).plot(kind='pie', autopct='%1.1f%%', ylabel='Healthy Recipe Positive Review (%)')
plt.title("Healthy Recipe Positive Review Distribution")
# Out:
# Text(0.5, 1.0, 'Healthy Recipe Positive Review Distribution')

# %%
reviews_df['ReviewDate'] = pd.to_datetime(reviews_df['ReviewDate'], errors='coerce')
reviews_df['YearMonth'] = reviews_df['ReviewDate'].dt.to_period('M')
reviews_df.groupby('YearMonth')['IsHealthConsciousUser'].mean().plot(xlabel='Year', ylabel='Percentage of Health-Conscious Users (%)', title='Share of Health-Conscious Users Over Time')
plt.title("Percentage of Health-Conscious Users Over Time")
# Out:
# /var/folders/8d/969k1hcn5072w6lnczwswjy00000gn/T/ipykernel_75590/11020719.py:2: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   reviews_df['YearMonth'] = reviews_df['ReviewDate'].dt.to_period('M')
# Text(0.5, 1.0, 'Percentage of Health-Conscious Users Over Time')

# %% [markdown]
# ## Explore Recipes Dataset

# %%
recipes_df = pd.read_csv('../data/processed_recipes_all.csv')

# %%
print(recipes_df.columns)
recipes_df.describe()
# Out:
# Index(['RecipeId', 'Name', 'Description', 'RecipeCategory', 'TotalTimeMinutes',
#        'TimeCategory', 'IngredientCount', 'ComplexityCategory', 'Calories',
#        'CalorieCategory', 'NutriScore', 'NutriScoreGrade', 'IsNutriHealthy',
#        'RecommendationScore', 'AvgRating', 'ReviewCount', 'PopularityScore',
#        'IsVegetarian', 'IsVegan', 'IsGlutenFree', 'IsLowCarb',
#        'HasHealthyIngredients', 'HasUnhealthyIngredients', 'MealType',
#        'IngredientList', 'RecipeServings', 'ServingSizeCategory', 'Calories.1',
#        'FatContent', 'SaturatedFatContent', 'CholesterolContent',
#        'SodiumContent', 'CarbohydrateContent', 'FiberContent', 'SugarContent',
#        'ProteinContent'],
#       dtype='object')
#             RecipeId  TotalTimeMinutes  IngredientCount       Calories  \
# count  522517.000000      5.225170e+05    522517.000000  522517.000000
# mean   271821.436970      2.545014e+02         0.995753     101.049457
# ...

# %%
sns.countplot(data=recipes_df, x='NutriScoreGrade', order=['A','B','C','D','E'])
plt.title('Nutri-Score Grade Distribution')
plt.show()

# %% [markdown]
# ## 🔢 Calorie Distribution by Nutri-Score Grade"

# %%
sns.boxplot(data=df, x='NutriScoreGrade', y='Calories', order=['A','B','C','D','E'])
plt.title('Calories vs Nutri-Score Grade')
plt.show()

# %%
print(recipes.head())
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0      38.0  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1      39.0                            Biryani      1567        elly9812
# 2      40.0                      Best Lemonade      1566  Stephen Little
# 3      41.0     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4      42.0                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime             DatePublished  \
# 0    PT24H    PT45M  PT24H45M 1999-08-09 21:46:00+00:00
# 1    PT25M     PT4H   PT4H25M 1999-08-29 13:12:00+00:00
# 2     PT5M    PT30M     PT35M 1999-09-05 19:52:00+00:00
# 3    PT20M    PT24H  PT24H20M 1999-09-03 14:54:00+00:00
# 4    PT30M    PT20M     PT50M 1999-09-19 06:19:00+00:00
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# ...

# %%
recipes.columns
# Out:
# Index(['RecipeId', 'Name', 'AuthorId', 'AuthorName', 'CookTime', 'PrepTime',
#        'TotalTime', 'DatePublished', 'Description', 'Images', 'RecipeCategory',
#        'Keywords', 'RecipeIngredientQuantities', 'RecipeIngredientParts',
#        'AggregatedRating', 'ReviewCount', 'Calories', 'FatContent',
#        'SaturatedFatContent', 'CholesterolContent', 'SodiumContent',
#        'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent',
#        'RecipeServings', 'RecipeYield', 'RecipeInstructions'],
#       dtype='object')

# %%
print(reviews.head())
# Out:
#    ReviewId  RecipeId  AuthorId        AuthorName  Rating  \
# 0         2       992      2008         gayg msft       5
# 1         7      4384      1634     Bill Hilbrich       4
# 2         9      4523      2046  Gay Gilmore ckpt       2
# 3        13      7435      1773     Malarkey Test       5
# 4        14        44      2085        Tony Small       5
#
#                                               Review  \
# 0       better than any you can get at a restaurant!
# 1  I cut back on the mayo, and made up the differ...
# 2  i think i did something wrong because i could ...
# 3  easily the best i have ever had.  juicy flavor...
# 4                                 An excellent dish.
#
#               DateSubmitted              DateModified
# 0 2000-01-25 21:44:00+00:00 2000-01-25 21:44:00+00:00
# 1 2001-10-17 16:49:59+00:00 2001-10-17 16:49:59+00:00
# 2 2000-02-25 09:00:00+00:00 2000-02-25 09:00:00+00:00
# 3 2000-03-13 21:15:00+00:00 2000-03-13 21:15:00+00:00
# ...
